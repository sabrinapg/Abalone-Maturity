# %%
# !pip install ucimlrepo
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
import sklearn.linear_model as skl_lm
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import sklearn.linear_model as skl_lm
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score, LeaveOneOut, KFold
from sklearn.model_selection import KFold, cross_val_score
from sklearn.utils import resample
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.model_selection import cross_val_predict
from sklearn.tree import DecisionTreeRegressor, export_graphviz
import graphviz
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# Requirement already satisfied: ucimlrepo in /Users/sabrina/anaconda3/lib/python3.10/site-packages (0.0.6)

# %% [markdown]
# ### Sabrina's Notes
#
# `ucimlr` package provides easy access to datasets from the UC Irvine Machine Learning Repository (UCI MLR).
#
# Reference: https://github.com/uci-ml-repo/ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# %%
# fetch dataset (the id is found on 'cite' in the UCI website)
abalone = fetch_ucirepo(id=1)

# %%
print(abalone.variables)
# Out:
#              name     role         type demographic  \
# 0             Sex  Feature  Categorical        None
# 1          Length  Feature   Continuous        None
# 2        Diameter  Feature   Continuous        None
# 3          Height  Feature   Continuous        None
# 4    Whole_weight  Feature   Continuous        None
# 5  Shucked_weight  Feature   Continuous        None
# 6  Viscera_weight  Feature   Continuous        None
# 7    Shell_weight  Feature   Continuous        None
# 8           Rings   Target      Integer        None
#
#                    description  units missing_values
# 0         M, F, and I (infant)   None             no
# 1    Longest shell measurement     mm             no
# 2      perpendicular to length     mm             no
# 3           with meat in shell     mm             no
# 4                whole abalone  grams             no
# 5               weight of meat  grams             no
# 6  gut weight (after bleeding)  grams             no
# 7            after being dried  grams             no
# 8  +1.5 gives the age in years   None             no

# %%
# Metadata
print(abalone.metadata)

# Dataset note :+1.5 gives the age in years
# Out:
# {'uci_id': 1, 'name': 'Abalone', 'repository_url': 'https://archive.ics.uci.edu/dataset/1/abalone', 'data_url': 'https://archive.ics.uci.edu/static/public/1/data.csv', 'abstract': 'Predict the age of abalone from physical measurements', 'area': 'Biology', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Tabular'], 'num_instances': 4177, 'num_features': 8, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': [], 'target_col': ['Rings'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1994, 'last_updated': 'Mon Aug 28 2023', 'dataset_doi': '10.24432/C55C7W', 'creators': ['Warwick Nash', 'Tracy Sellers', 'Simon Talbot', 'Andrew Cawthorn', 'Wes Ford'], 'intro_paper': None, 'additional_info': {'summary': 'Predicting the age of abalone from physical measurements.  The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task.  Other measurements, which are easier to obtain, are used to predict the age.  Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.\r\n\r\nFrom the original data examples with missing values were removed (the majority having the predicted value missing), and the ranges of the continuous values have been scaled for use with an ANN (by dividing by 200).', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Given is the attribute name, attribute type, the measurement unit and a brief description.  The number of rings is the value to predict: either as a continuous value or as a classification problem.\r\n\r\nName / Data Type / Measurement Unit / Description\r\n-----------------------------\r\nSex / nominal / -- / M, F, and I (infant)\r\nLength / continuous / mm / Longest shell measurement\r\nDiameter\t/ continuous / mm / perpendicular to length\r\nHeight / continuous / mm / with meat in shell\r\nWhole weight / continuous / grams / whole abalone\r\nShucked weight / continuous\t / grams / weight of meat\r\nViscera weight / continuous / grams / gut weight (after bleeding)\r\nShell weight / continuous / grams / after being dried\r\nRings / integer / -- / +1.5 gives the age in years\r\n\r\nThe readme file contains attribute statistics.', 'citation': None}}

# %%
abalone.data.original
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df=abalone.data.original
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole_weight    4177 non-null   float64
#  5   Shucked_weight  4177 non-null   float64
#  6   Viscera_weight  4177 non-null   float64
#  7   Shell_weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.describe().T
# Out:
#                  count      mean       std     min     25%     50%     75%  \
# Length          4177.0  0.523992  0.120093  0.0750  0.4500  0.5450   0.615
# Diameter        4177.0  0.407881  0.099240  0.0550  0.3500  0.4250   0.480
# Height          4177.0  0.139516  0.041827  0.0000  0.1150  0.1400   0.165
# Whole_weight    4177.0  0.828742  0.490389  0.0020  0.4415  0.7995   1.153
# Shucked_weight  4177.0  0.359367  0.221963  0.0010  0.1860  0.3360   0.502
# Viscera_weight  4177.0  0.180594  0.109614  0.0005  0.0935  0.1710   0.253
# Shell_weight    4177.0  0.238831  0.139203  0.0015  0.1300  0.2340   0.329
# Rings           4177.0  9.933684  3.224169  1.0000  8.0000  9.0000  11.000
#
#                     max
# Length           0.8150
# Diameter         0.6500
# Height           1.1300
# Whole_weight     2.8255
# Shucked_weight   1.4880
# Viscera_weight   0.7600
# Shell_weight     1.0050
# Rings           29.0000

# %%
# Add 1.5 to rings for get age
df['Age'] = df['Rings'] + 1.5

# %%
# We dont need rings column
df.drop("Rings",axis=1,inplace=True)
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
# Check null values
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Age               0
# dtype: int64

# %%
# Values of this dataset can not be zero, check zeros
(df==0).any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height             True
# Whole_weight      False
# Shucked_weight    False
# Viscera_weight    False
# Shell_weight      False
# Age               False
# dtype: bool

# %%
df[df["Height"]==0]
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 1257   I   0.430      0.34     0.0         0.428          0.2065
# 3996   I   0.315      0.23     0.0         0.134          0.0575
#
#       Viscera_weight  Shell_weight  Age
# 1257          0.0860        0.1150  9.5
# 3996          0.0285        0.3505  7.5

# %%
# We can delete these rows 2 in 4177
df = df.drop(df[df["Height"]==0].index)

# %%
# Check values
df[df["Height"]==0]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole_weight, Shucked_weight, Viscera_weight, Shell_weight, Age]
# Index: []

# %%
# Reset indexes
df.reset_index(inplace=True)
df.drop("index",axis=1,inplace=True)

# %%
# Check columns
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
df.Age.value_counts()
# Out:
# 10.5    689
# 11.5    634
# 9.5     567
# 12.5    487
# 8.5     391
# 13.5    267
# 7.5     258
# 14.5    203
# 15.5    126
# 6.5     115
# 16.5    103
# 17.5     67
# 18.5     58
# 5.5      57
# 19.5     42
# 20.5     32
# 21.5     26
# 4.5      15
# 22.5     14
# 24.5      9
# 23.5      6
# 28.5      2
# 25.5      2
# 2.5       1
# 27.5      1
# 30.5      1
# 3.5       1
# 26.5      1
# Name: Age, dtype: int64

# %%
# Check relationship between columns, there is some outlier values
# sns.pairplot(df)

# %%
# Select target columns
target_columns=[]
df_temp=df.drop(["Sex","Age"],axis=1)
target_columns=df_temp.columns.to_list()
target_columns
# Out:
# ['Length',
#  'Diameter',
#  'Height',
#  'Whole_weight',
#  'Shucked_weight',
#  'Viscera_weight',
#  'Shell_weight']

# %% [markdown]
# ### Sabrina's Notes
#
# Detecting outliers
#
# Reference: https://stackoverflow.com/questions/66966605/outliers-formula-for-columns-in-pandas
# Reference: https://gist.github.com/joseph-allen/14d72af86689c99e1e225e5771ce1600?permalink_comment_id=3554420
# Reference: https://community.dataquest.io/t/detecting-outliers-and-deleting-them-in-python-or-r/8448/2
#
# The code below goes through each characteristic of a dataset, such as age or height, checking for unusual values that don't fit the typical range. It figures out what the "normal" range of values is by looking at where most of the data falls (25% below and 75% below). Then, it marks anything far outside this range as unusual, and if there are too many unusual values, it removes them from the dataset. This helps make sure the dataset is accurate and useful for analysis, without any strange or incorrect data messing things up.

# %%
# Detect outliers

for i in df.columns:
  if i in target_columns :
        # 1st quartile
        Q1 = np.percentile(df[i],25)
        # 3rd quartile
        Q3 = np.percentile(df[i],75)
        # IQR calculation
        IQR = Q3 - Q1
        # Range calculation
        lower_bound = Q1 - (IQR * 1.5)
        upper_bound = Q3 + (IQR * 1.5)
        # Outlier detection
        print("Range of " + i  + " : "+ str(lower_bound)  + " - " + str(upper_bound))
        outliers = df[(df[i] <= lower_bound) | (df[i] >= upper_bound)]
        # Print outlier count
        print(f"Outlier count for column {i} : {len(outliers)}")
        # Delete outliers
        df = df[(df[i] >= lower_bound) & (df[i] <= upper_bound)]
# Out:
# Range of Length : 0.20250000000000004 - 0.8624999999999999
# Outlier count for column Length : 49
# Range of Diameter : 0.15499999999999997 - 0.675
# Outlier count for column Diameter : 12
# Range of Height : 0.039999999999999994 - 0.24000000000000002
# Outlier count for column Height : 6
# Range of Whole_weight : -0.6031874999999999 - 2.2173125
# Outlier count for column Whole_weight : 28
# Range of Shucked_weight : -0.27324999999999994 - 0.9647499999999999
# Outlier count for column Shucked_weight : 25
# Range of Viscera_weight : -0.13549999999999998 - 0.4805
# Outlier count for column Viscera_weight : 15
# Range of Shell_weight : -0.15325 - 0.60875
# Outlier count for column Shell_weight : 28

# %%
# Check row count
df.describe().T
# Out:
#                  count       mean       std     min     25%      50%      75%  \
# Length          4013.0   0.524533  0.110511  0.2050  0.4500   0.5400   0.6100
# Diameter        4013.0   0.408242  0.091758  0.1550  0.3500   0.4200   0.4800
# Height          4013.0   0.139090  0.035588  0.0400  0.1150   0.1400   0.1650
# Whole_weight    4013.0   0.809481  0.445060  0.0425  0.4475   0.7945   1.1330
# Shucked_weight  4013.0   0.350871  0.200989  0.0170  0.1890   0.3340   0.4935
# Viscera_weight  4013.0   0.176759  0.100637  0.0005  0.0950   0.1690   0.2465
# Shell_weight    4013.0   0.233437  0.125749  0.0130  0.1315   0.2300   0.3200
# Age             4013.0  11.442935  3.117503  4.5000  9.5000  10.5000  12.5000
#
#                     max
# Length           0.7600
# Diameter         0.6000
# Height           0.2400
# Whole_weight     2.1275
# Shucked_weight   0.9600
# Viscera_weight   0.4805
# Shell_weight     0.6050
# Age             30.5000

# %%
# Reset index
df.reset_index(inplace=True)
df.drop("index",axis=1,inplace=True)

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
# Extract dummy variables
Sex_dummies = pd.get_dummies(df['Sex'], prefix='Sex')
df = pd.concat([df, Sex_dummies], axis=1)
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight   Age  Sex_F  Sex_I  Sex_M
# 0         0.150  16.5      0      0      1
# 1         0.070   8.5      0      0      1
# 2         0.210  10.5      1      0      0
# 3         0.155  11.5      0      0      1
# 4         0.055   8.5      0      1      0

# %%
# Replace age column place
columns = list(df.columns)
columns.append(columns.pop(columns.index('Age')))
df = df[columns]
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Sex_F  Sex_I  Sex_M   Age
# 0         0.150      0      0      1  16.5
# 1         0.070      0      0      1   8.5
# 2         0.210      1      0      0  10.5
# 3         0.155      0      0      1  11.5
# 4         0.055      0      1      0   8.5

# %%
# Drop Sex column
df=df.drop("Sex",axis=1)
df.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Sex_F  Sex_I  Sex_M   Age
# 0         0.150      0      0      1  16.5
# 1         0.070      0      0      1   8.5
# 2         0.210      1      0      0  10.5
# 3         0.155      0      0      1  11.5
# 4         0.055      0      1      0   8.5

# %%
# Print final dataframe
df.to_excel("Abolone.xlsx", index=False)

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole_weight  Shucked_weight  \
# Length          1.000000  0.985519  0.889740      0.940036        0.913472
# Diameter        0.985519  1.000000  0.896402      0.939106        0.906991
# Height          0.889740  0.896402  1.000000      0.891478        0.837605
# Whole_weight    0.940036  0.939106  0.891478      1.000000        0.968244
# Shucked_weight  0.913472  0.906991  0.837605      0.968244        1.000000
# Viscera_weight  0.912445  0.907697  0.867697      0.964702        0.926837
# Shell_weight    0.915753  0.923392  0.898255      0.958049        0.886797
# Sex_F           0.306682  0.316169  0.316342      0.310763        0.275887
# Sex_I          -0.540366 -0.554254 -0.549196     -0.561065       -0.523608
# Sex_M           0.228107  0.232421  0.227348      0.244243        0.241570
# Age             0.516975  0.537673  0.578849      0.516195        0.392160
#
#                 Viscera_weight  Shell_weight     Sex_F     Sex_I     Sex_M  \
# Length                0.912445      0.915753  0.306682 -0.540366  0.228107
# Diameter              0.907697      0.923392  0.316169 -0.554254  0.232421
# Height                0.867697      0.898255  0.316342 -0.549196  0.227348
# Whole_weight          0.964702      0.958049  0.310763 -0.561065  0.244243
# Shucked_weight        0.926837      0.886797  0.275887 -0.523608  0.241570
# Viscera_weight        1.000000      0.912473  0.316736 -0.557414  0.234938
# Shell_weight          0.912473      1.000000  0.314563 -0.552794  0.232555
# Sex_F                 0.316736      0.314563  1.000000 -0.465652 -0.513319
# Sex_I                -0.557414     -0.552794 -0.465652  1.000000 -0.520449
# Sex_M                 0.234938      0.232555 -0.513319 -0.520449  1.000000
# Age                   0.480007      0.605703  0.240835 -0.418521  0.173483
#
#                      Age
# Length          0.516975
# Diameter        0.537673
# Height          0.578849
# Whole_weight    0.516195
# Shucked_weight  0.392160
# Viscera_weight  0.480007
# Shell_weight    0.605703
# Sex_F           0.240835
# Sex_I          -0.418521
# Sex_M           0.173483
# Age             1.000000

# %% [markdown]
# # Resampling Part

# %% [markdown]
# References:
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
# https://stackoverflow.com/questions/43519160/matplotlib-scatter-plot-with-colormaps-for-edgecolor-but-no-facecolor

# %%
columns = df.columns.drop(['Age',"Sex_I","Sex_M","Sex_F"])

for col in columns:
    plt.scatter(df[col], df['Age'], facecolors='None', edgecolors='k', alpha=0.8)
    sns.regplot(x=df[col], y=df['Age'], ci=None, label='Linear', scatter=False, color='orange')
    sns.regplot(x=df[col], y=df['Age'], ci=None, label='Degree 5', order=5, scatter=False, color='g')
    plt.xlabel(col)
    plt.ylabel('Age')  # Corrected line: plt.ylabel instead of plt.ylacolumns
    plt.title(f'{col} vs Age')
    plt.legend()
    plt.show()

# %%
independent_vars = df.columns.drop(['Age'])

# Regression model
formula = 'Age ~ ' + ' + '.join(independent_vars)
# OLS model
model = smf.ols(formula, data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Age   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     483.2
# Date:                Thu, 11 Jul 2024   Prob (F-statistic):               0.00
# Time:                        19:04:08   Log-Likelihood:                -8781.1
# No. Observations:                4013   AIC:                         1.758e+04
# Df Residuals:                    4003   BIC:                         1.765e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          4.0601      0.253     16.027      0.000       3.563       4.557
# Length            -2.2150      1.915     -1.156      0.248      -5.970       1.540
# Diameter           8.7887      2.340      3.757      0.000       4.202      13.375
# Height            22.1579      2.412      9.186      0.000      17.429      26.887
# Whole_weight       9.3201      0.766     12.167      0.000       7.818      10.822
# Shucked_weight   -20.8367      0.872    -23.908      0.000     -22.545     -19.128
# Viscera_weight   -11.9318      1.366     -8.737      0.000     -14.609      -9.254
# Shell_weight      10.2202      1.275      8.018      0.000       7.721      12.719
# Sex_F              1.6064      0.107     15.049      0.000       1.397       1.816
# Sex_I              0.8096      0.094      8.645      0.000       0.626       0.993
# Sex_M              1.6442      0.101     16.327      0.000       1.447       1.842
# ==============================================================================
# Omnibus:                      869.189   Durbin-Watson:                   1.448
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2357.750
# Skew:                           1.148   Prob(JB):                         0.00
# Kurtosis:                       5.971   Cond. No.                     1.20e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.79e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# References:
# The .join method is a string method in Python that is used to concatenate a sequence of strings with a specified separator, which was useful to connect the independant variable to OLS
# https://stackoverflow.com/questions/76994016/loop-regression-models-and-combine-them-in-modelsummary-r
# https://stackoverflow.com/questions/19991445/run-an-ols-regression-with-pandas-data-frame

# %% [markdown]
# correlation_matrix = df.corr()
# plt.figure(figsize=(12, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
# plt.title('Correlation Matrix')
# plt.show()

# %% [markdown]
# References:
# https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e

# %%
X = df[independent_vars]
y = df['Age']
std_reg = LinearRegression().fit(X, y)
print("Regression Coefficients:", std_reg.coef_)
# Out:
# Regression Coefficients: [-1.74516645e+00  8.34256633e+00  2.21645159e+01  9.41002816e+00
#  -2.09297998e+01 -1.20273057e+01  1.00527850e+01 -1.55093733e+14
#  -1.55093733e+14 -1.55093733e+14]

# %%
std_X = X.std()
std_y = y.std()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
y_scaled = (y - y.mean()) / y.std()

std_reg = LinearRegression().fit(X_scaled, y_scaled)

std_beta_coefficients = std_reg.coef_

for i, col in enumerate(independent_vars):
    std_var = std_X[i]
    beta_var = std_beta_coefficients[i]
    change_in_age = beta_var * std_y
    print(f"A one standard deviation change in {col} ({std_var:.2f}) results in a change of {change_in_age:.2f} units in the age variable.")
# Out:
# A one standard deviation change in Length (0.11) results in a change of -0.26 units in the age variable.
# A one standard deviation change in Diameter (0.09) results in a change of 0.83 units in the age variable.
# A one standard deviation change in Height (0.04) results in a change of 0.77 units in the age variable.
# A one standard deviation change in Whole_weight (0.45) results in a change of 4.15 units in the age variable.
# A one standard deviation change in Shucked_weight (0.20) results in a change of -4.20 units in the age variable.
# A one standard deviation change in Viscera_weight (0.10) results in a change of -1.20 units in the age variable.
# A one standard deviation change in Shell_weight (0.13) results in a change of 1.28 units in the age variable.
# A one standard deviation change in Sex_F (0.46) results in a change of -33324578660633.21 units in the age variable.
# A one standard deviation change in Sex_I (0.47) results in a change of -33492598565047.82 units in the age variable.
# A one standard deviation change in Sex_M (0.48) results in a change of -34537340971556.73 units in the age variable.

# %%
df.describe().T
# Out:
#                  count       mean       std     min     25%      50%      75%  \
# Length          4013.0   0.524533  0.110511  0.2050  0.4500   0.5400   0.6100
# Diameter        4013.0   0.408242  0.091758  0.1550  0.3500   0.4200   0.4800
# Height          4013.0   0.139090  0.035588  0.0400  0.1150   0.1400   0.1650
# Whole_weight    4013.0   0.809481  0.445060  0.0425  0.4475   0.7945   1.1330
# Shucked_weight  4013.0   0.350871  0.200989  0.0170  0.1890   0.3340   0.4935
# Viscera_weight  4013.0   0.176759  0.100637  0.0005  0.0950   0.1690   0.2465
# Shell_weight    4013.0   0.233437  0.125749  0.0130  0.1315   0.2300   0.3200
# Sex_F           4013.0   0.314727  0.464465  0.0000  0.0000   0.0000   1.0000
# Sex_I           4013.0   0.320708  0.466807  0.0000  0.0000   0.0000   1.0000
# Sex_M           4013.0   0.364565  0.481368  0.0000  0.0000   0.0000   1.0000
# Age             4013.0  11.442935  3.117503  4.5000  9.5000  10.5000  12.5000
#
#                     max
# Length           0.7600
# Diameter         0.6000
# Height           0.2400
# Whole_weight     2.1275
# Shucked_weight   0.9600
# Viscera_weight   0.4805
# Shell_weight     0.6050
# Sex_F            1.0000
# Sex_I            1.0000
# Sex_M            1.0000
# Age             30.5000

# %% [markdown]
# ### Sabrina's Notes
# The Abalone dataset has a numerical target variable, age, instead of a categorical one like: Direction.
# So if I want to create a classification problem (e.g., predicting if age is above a certain threshold),
# I can use logistic regression.

# %%
df['Direction'] = np.where(df['Age'] >= 10, 'Old', 'Young')

# %%
formula = 'Direction ~ Length + Diameter + Height + Whole_weight + Shucked_weight + Viscera_weight + Shell_weight'
model = smf.glm(formula=formula, data=df, family=sm.families.Binomial()).fit()
print(model.summary())
# Out:
#                            Generalized Linear Model Regression Results
# ==================================================================================================
# Dep. Variable:     ['Direction[Old]', 'Direction[Young]']   No. Observations:                 4013
# Model:                                                GLM   Df Residuals:                     4005
# Model Family:                                    Binomial   Df Model:                            7
# Link Function:                                      Logit   Scale:                          1.0000
# Method:                                              IRLS   Log-Likelihood:                -1504.5
# Date:                                    Thu, 11 Jul 2024   Deviance:                       3008.9
# Time:                                            19:04:09   Pearson chi2:                 4.86e+03
# No. Iterations:                                         7   Pseudo R-squ. (CS):             0.4085
# Covariance Type:                                nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -4.1098      0.541     -7.603      0.000      -5.169      -3.050
# Length            -7.6437      2.712     -2.819      0.005     -12.958      -2.329
# Diameter           9.8300      3.333      2.949      0.003       3.297      16.363
# Height            17.2261      3.569      4.826      0.000      10.230      24.222
# Whole_weight       6.7254      1.438      4.678      0.000       3.908       9.543
# Shucked_weight   -15.5876      1.652     -9.434      0.000     -18.826     -12.349
# Viscera_weight    -0.7830      2.355     -0.332      0.740      -5.400       3.834
# Shell_weight      14.3696      2.246      6.397      0.000       9.967      18.772
# ==================================================================================

# %%
predictions = model.predict(df)

# %%
predictions_nominal = ['Old' if x > 0.5 else 'Young' for x in predictions]

# %%
print(confusion_matrix(df['Direction'], predictions_nominal))
# Out:
# [[2367  303]
#  [ 373  970]]

# %%
print(classification_report(df['Direction'], predictions_nominal, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#          Old      0.864     0.887     0.875      2670
#        Young      0.762     0.722     0.742      1343
#
#     accuracy                          0.832      4013
#    macro avg      0.813     0.804     0.808      4013
# weighted avg      0.830     0.832     0.830      4013

# %% [markdown]
# ### Sabrina's Notes
#
# The classification report shows that the logistic regression model performs well overall, with an accuracy of 83.2%.
#  For the "Old" class, it achieves high precision (86.4%) and recall (88.7%), indicating reliable identification of older instances.
#   For the "Young" class, the precision is 76.2% and recall is 72.2%, showing good but slightly lower performance compared to the "Old" class.
#   Overall, the model demonstrates strong predictive capabilities with balanced precision and recall.

# %% [markdown]
# ### Sabrina's Notes
# I will apply a logistic regression model to the Abalone dataset to classify whether an abalone's age is above or below a certain threshold (e.g., 10 years)

# %%
X = df.drop(["Age","Direction"],axis=1)
y = df['Direction']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
log_reg = LogisticRegression().fit(X_train, y_train)

# %%
print(log_reg.coef_)
# Out:
# [[-1.82059874 -2.50835952 -1.9795788  -2.95693491  5.30582109 -0.73693099
#   -5.58788312 -0.42183953  0.71937857 -0.29717653]]

# %%
y_pred_prob = log_reg.predict_proba(X_test)[:, 1]

# %%
y_pred = ['Old' if x > 0.5 else 'Young' for x in y_pred_prob]

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 75 589]
#  [238 102]]

# %%
print(classification_report(y_test, y_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#          Old      0.240     0.113     0.154       664
#        Young      0.148     0.300     0.198       340
#
#     accuracy                          0.176      1004
#    macro avg      0.194     0.206     0.176      1004
# weighted avg      0.208     0.176     0.169      1004

# %% [markdown]
# ## Preparing Dataset

# %%
df.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Sex_F  Sex_I  Sex_M   Age Direction
# 0         0.150      0      0      1  16.5       Old
# 1         0.070      0      0      1   8.5     Young
# 2         0.210      1      0      0  10.5       Old
# 3         0.155      0      0      1  11.5       Old
# 4         0.055      0      1      0   8.5     Young

# %%
df["Sex_I"].replace({False: 0, True: 1}, inplace=True)
df["Sex_F"].replace({False: 0, True: 1}, inplace=True)
df["Sex_M"].replace({False: 0, True: 1}, inplace=True)

df.drop(["Direction"],axis=1,inplace=True)

# %%
X = df.drop(columns=['Age'])
y = df['Age']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train = X_train.values
y_train = y_train.values
X_test = X_test.values
y_test = y_test.values

# %%
# Linear Regression
lm = skl_lm.LinearRegression()
model = lm.fit(X_train, y_train)

pred = model.predict(X_test)

MSE = mean_squared_error(y_test, pred)
print(f'Linear Regression MSE: {MSE}')
# Out:
# Linear Regression MSE: 4.584462823145893

# %%
r2 = r2_score(y_test, pred)
print(f'Linear Regression R2 Score: {r2}')
# Out:
# Linear Regression R2 Score: 0.5381143277906365

# %%
# Polynomial Regression Quadratic & Cubic
# Quadratic Model
poly = PolynomialFeatures(degree=2)
X_train2 = poly.fit_transform(X_train)
X_test2 = poly.fit_transform(X_test)
model2 = lm.fit(X_train2, y_train)
MSE2 = mean_squared_error(y_test, model2.predict(X_test2))
print(f'Quadratic Regression MSE: {MSE2}')

# Cubic Model
poly = PolynomialFeatures(degree=3)
X_train3 = poly.fit_transform(X_train)
X_test3 = poly.fit_transform(X_test)
model3 = lm.fit(X_train3, y_train)
MSE3 = mean_squared_error(y_test, model3.predict(X_test3))
print(f'Cubic Regression MSE: {MSE3}')
# Out:
# Quadratic Regression MSE: 4.227475823634174
# Cubic Regression MSE: 5.287005937431913

# %%
# Leave-One-Out Cross-Validation (LOOCV)
loo = LeaveOneOut()
X = df.drop(columns=["Age"]).values
Y = df['Age'].values

crossvalidation = KFold(n_splits=len(df), random_state=None, shuffle=False)
scores = cross_val_score(model, X, Y, scoring="neg_mean_squared_error", cv=crossvalidation, n_jobs=1)
print("Folds: " + str(len(scores)) + ", MSE: " + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)))
# Out:
# Folds: 4013, MSE: 4.695014978506617, STD: 10.506065058521795

# %% [markdown]
# The code below takes a long time to load:

# %%
# k-Fold Cross-Validation
lm = LinearRegression()
crossvalidation = KFold(n_splits=10, random_state=1, shuffle=True)
for i in range(1, 11):
    poly = PolynomialFeatures(degree=i)
    X_current = poly.fit_transform(X)
    model = lm.fit(X_current, y)
    scores = cross_val_score(model, X_current, y, scoring="neg_mean_squared_error", cv=crossvalidation, n_jobs=1)
    print("Degree-" + str(i) + " polynomial MSE: " + str(np.mean(np.abs(scores))) + ", STD: " + str(np.std(scores)))
# Out:
# Degree-1 polynomial MSE: 4.698334011201965, STD: 0.4487008812391235
# Degree-2 polynomial MSE: 4.403694403559916, STD: 0.49526440726545484
# Degree-3 polynomial MSE: 4.921231496027998, STD: 0.5666926969530767
# Degree-4 polynomial MSE: 34.80248972227986, STD: 56.529024859619234
# Degree-5 polynomial MSE: 10493.675161531643, STD: 16046.066379903717
# Degree-6 polynomial MSE: 368651825.29214674, STD: 469548105.4690209
# Degree-7 polynomial MSE: 9500301585.011177, STD: 7510437103.350737
# Degree-8 polynomial MSE: 45430140222.40567, STD: 113968811042.82635
# Degree-9 polynomial MSE: 156077123922.3061, STD: 423357785189.41693

# %%
# Bootstrap
lm = skl_lm.LinearRegression()
clf = lm.fit(X,y)
y_pred = clf.predict(X)
rmse_original = np.sqrt(mean_squared_error(y, y_pred))
print("Original Model RMSE:", rmse_original)
# Out:
# Original Model RMSE: 2.159429062830834

# %%
Xsamp, ysamp = resample(X, y, n_samples = 500)
clf = lm.fit(Xsamp, ysamp)
y_pred = clf.predict(X)
rmse_ = np.sqrt(mean_squared_error(y, y_pred))
print(" 500 Sample RMSE:", rmse_)
# Out:
#  500 Sample RMSE: 2.197490361002117

# %%
Xsamp, ysamp = resample(X, y, n_samples = 1500)
clf = lm.fit(Xsamp, ysamp)
y_pred = clf.predict(X)
rmse_ = np.sqrt(mean_squared_error(y, y_pred))
print(" 1500 Sample RMSE:", rmse_)
# Out:
#  1500 Sample RMSE: 2.1659658588582174

# %%
Xsamp, ysamp = resample(X, y, n_samples = 2000)
clf = lm.fit(Xsamp, ysamp)
y_pred = clf.predict(X)
rmse_ = np.sqrt(mean_squared_error(y, y_pred))
print(" 2000 Sample RMSE:", rmse_)
# Out:
#  2000 Sample RMSE: 2.161361172068441

# %% [markdown]
# ## Resampling Note:
# Even if the sample size changes, the RMSE values provide insight into the model's prediction accuracy and stability.
# If the RMSE values are consistent across different bootstrap samples, it indicates that the model's predictions are stable and reliable.

# %% [markdown]
# # Forecasting

# %%
from sklearn.linear_model import Ridge, RidgeCV, Lasso
from sklearn.model_selection import cross_val_predict
from sklearn.tree import DecisionTreeRegressor, export_graphviz
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## How to install Graphviz System Package on MacOS
# In terminal, run:
# /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
#
# Check if in PATH, if not - run:
#
# (echo; echo 'eval "$(/opt/homebrew/bin/brew shellenv)"') >> /Users/sabrina/.zprofile
#
# eval "$(/opt/homebrew/bin/brew shellenv)"
#
# Otherwise run:
# brew install graphviz
#
# Verify package:
# brew help
#
# Finally, in terminal:
# pip install numpy pandas scikit-learn graphviz

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /Users/sabrina/anaconda3/lib/python3.10/site-packages (0.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import graphviz

# %%
df.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Sex_F  Sex_I  Sex_M   Age
# 0         0.150      0      0      1  16.5
# 1         0.070      0      0      1   8.5
# 2         0.210      1      0      0  10.5
# 3         0.155      0      0      1  11.5
# 4         0.055      0      1      0   8.5

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.metrics import mean_squared_error

# %%
alphas = 10**np.linspace(10, -2, 100)*0.5
ridge = Ridge()
coefs = []

# %%
for a in alphas:
    ridge.set_params(alpha=a)
    ridge.fit(X_train, y_train)
    coefs.append(ridge.coef_)

# %%
ridge_model = RidgeCV(alphas=alphas, scoring='neg_mean_squared_error')

# %%
ridge_model.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        3.06795364e+00, 2.32079442e+00, 1.75559587e+00, 1.32804389e+00,
#        1.00461650e+00, 7.59955541e-01, 5.74878498e-01, 4.34874501e-01,
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         scoring='neg_mean_squared_error')

# %%
ridge_best_alpha = ridge_model.alpha_
print(ridge_best_alpha)
# Out:
# 0.0466301673441609

# %%
ridge_best_model = Ridge(alpha=ridge_best_alpha)

# %%
ridge_best_model.fit(X_train, y_train)
ridge_pred = ridge_best_model.predict(X_test)
ridge_mse = mean_squared_error(y_test, ridge_pred)
print(f'Ridge Regression MSE: {ridge_mse}')
# Out:
# Ridge Regression MSE: 4.534909486395935

# %%
df.describe().T
# Out:
#                  count       mean       std     min     25%      50%      75%  \
# Length          4013.0   0.524533  0.110511  0.2050  0.4500   0.5400   0.6100
# Diameter        4013.0   0.408242  0.091758  0.1550  0.3500   0.4200   0.4800
# Height          4013.0   0.139090  0.035588  0.0400  0.1150   0.1400   0.1650
# Whole_weight    4013.0   0.809481  0.445060  0.0425  0.4475   0.7945   1.1330
# Shucked_weight  4013.0   0.350871  0.200989  0.0170  0.1890   0.3340   0.4935
# Viscera_weight  4013.0   0.176759  0.100637  0.0005  0.0950   0.1690   0.2465
# Shell_weight    4013.0   0.233437  0.125749  0.0130  0.1315   0.2300   0.3200
# Sex_F           4013.0   0.314727  0.464465  0.0000  0.0000   0.0000   1.0000
# Sex_I           4013.0   0.320708  0.466807  0.0000  0.0000   0.0000   1.0000
# Sex_M           4013.0   0.364565  0.481368  0.0000  0.0000   0.0000   1.0000
# Age             4013.0  11.442935  3.117503  4.5000  9.5000  10.5000  12.5000
#
#                     max
# Length           0.7600
# Diameter         0.6000
# Height           0.2400
# Whole_weight     2.1275
# Shucked_weight   0.9600
# Viscera_weight   0.4805
# Shell_weight     0.6050
# Sex_F            1.0000
# Sex_I            1.0000
# Sex_M            1.0000
# Age             30.5000

# %% [markdown]
# ### Ridge with scaling

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
alphas = 10**np.linspace(10, -2, 100)*0.5
ridge_model = RidgeCV(alphas=alphas, scoring='neg_mean_squared_error')
ridge_model.fit(X_train_scaled, y_train)
ridge_best_alpha = ridge_model.alpha_
ridge_best_model = Ridge(alpha=ridge_best_alpha)
ridge_best_model.fit(X_train_scaled, y_train)
# Out:
# Ridge(alpha=1.328043891473342)

# %%
ridge_pred = ridge_best_model.predict(X_test_scaled)
ridge_mse = mean_squared_error(y_test, ridge_pred)
print(f'Ridge Regression MSE: {ridge_mse}')
# Out:
# Ridge Regression MSE: 4.5359338758656955

# %% [markdown]
# ### Sabrina's Note:
# MSE didnt change after scaling

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import LassoCV
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
lasso = Lasso(max_iter=10000)
coefs = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    coefs.append(lasso.coef_)

# %%
lasso_model = LassoCV(alphas=alphas, max_iter=10000, cv=10)
lasso_model.fit(X_train, y_train)
# Out:
# LassoCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        3.06795364e+00, 2.32079442e+00, 1.75559587e+00, 1.32804389e+00,
#        1.00461650e+00, 7.59955541e-01, 5.74878498e-01, 4.34874501e-01,
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         cv=10, max_iter=10000)

# %%
lasso_best_alpha = lasso_model.alpha_
print(lasso_best_alpha)
# Out:
# 0.005

# %%
lasso_best_model = Lasso(alpha=lasso_best_alpha)
lasso_best_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.005)

# %%
lasso_pred = lasso_best_model.predict(X_test)
lasso_mse = mean_squared_error(y_test, lasso_pred)
print(f'Lasso Regression MSE: {lasso_mse}')
# Out:
# Lasso Regression MSE: 4.721242294503113

# %% [markdown]
# ### Decision Tree Regressor

# %%
regr_tree = DecisionTreeRegressor()
regr_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# DEBUGGING FOR BELOW CODE

import os

# Add the directory containing dot to the PATH
os.environ['PATH'] += os.pathsep + '/opt/homebrew/bin'

# Verify it’s added
print("Updated PATH:", os.environ['PATH'])
   
from sklearn.tree import DecisionTreeRegressor, export_graphviz

# Export the tree to a .dot file
export_graphviz(regr_tree, out_file="Tree.dot", feature_names=df.drop(['Age'], axis=1).columns)

# Read the .dot file and visualize it
with open('Tree.dot') as f:
    dot_graph = f.read()
    
# Create a graph from the dot file content
graph = graphviz.Source(dot_graph)

# Display the graph
graph.render("Tree")  # This will create a Tree.pdf file
graph.view()  # This will open the Tree.pdf file if the viewer is available
# Out:
# Updated PATH: /Users/sabrina/anaconda3/bin:/Users/sabrina/anaconda3/condabin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/homebrew/bin
# 'Tree.pdf'

# %%
# Commented as it will not be able to let me print as PDF, the image is "Tree.pdf" sent with assignment on team

# export_graphviz(regr_tree, out_file="Tree.dot", feature_names=df.drop(['Age'], axis=1).columns)
# with open('Tree.dot') as f:
#    dot_graph = f.read()
# graphviz.Source(dot_graph)

# %%
pred = regr_tree.predict(X_test)

# %%
mse = mean_squared_error(y_test, pred)
print(f'Decision Tree Regression MSE: {mse}')
print(f'RMSE: {np.sqrt(mse)}')
# Out:
# Decision Tree Regression MSE: 8.829734219269103
# RMSE: 2.971486870115549

# %%
max_depths = range(1, 10)
mse_scores = []

# %%
for depth in max_depths:
    tree = DecisionTreeRegressor(max_depth=depth, random_state=0)
    y_pred = cross_val_predict(tree, X, y, cv=5)
    mse = mean_squared_error(y, y_pred)
    mse_scores.append(mse)

# %%
plt.figure(figsize=(10, 6))
plt.plot(max_depths, mse_scores, marker='o')
plt.title('MSE vs. Tree Depth')
plt.xlabel('Tree Depth')
plt.ylabel('Mean Squared Error')
plt.show()

# %%
# Regression with max depth 5
regr_tree = DecisionTreeRegressor(max_depth=5)
regr_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
pred = regr_tree.predict(X_test)
mse = mean_squared_error(y_test, pred)
print(f'Decision Tree Regression MSE: {mse}')
print(f'RMSE: {np.sqrt(mse)}')
# Out:
# Decision Tree Regression MSE: 5.33457293093215
# RMSE: 2.3096694419185075

# %% [markdown]
# ### Sabrina's Note:
# A smoother MSE value was obtained with a max depth of 5

# %%
bagged_model = RandomForestRegressor(max_features=X_train.shape[1], random_state=42)
bagged_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features=10, random_state=42)

# %%
bagged_pred = bagged_model.predict(X_test)
bagged_mse = mean_squared_error(y_test, bagged_pred)
print(f'Bagging Regressor MSE: {bagged_mse}')
print(f'RMSE: {np.sqrt(bagged_mse)}')
# Out:
# Bagging Regressor MSE: 4.567190282392026
# RMSE: 2.137098566372648

# %%
plt.scatter(bagged_pred, y_test, label='Age')
plt.plot([0, 1], [0, 1], '--k', transform=plt.gca().transAxes)
plt.xlabel('Predictions')
plt.ylabel('Actual')
plt.title('Bagging Model Predictions vs Actual')
plt.show()

# %%
rf_model = RandomForestRegressor(max_features=7, random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
rf_mse = mean_squared_error(y_test, rf_pred)
print(f'Random Forest Regressor MSE: {rf_mse}')
print(f'RMSE: {np.sqrt(rf_mse)}')
# Out:
# Random Forest Regressor MSE: 4.584501661129568
# RMSE: 2.141144941644439

# %%
importance = pd.DataFrame({'Importance': rf_model.feature_importances_ * 100}, index=df.drop(['Age'],axis=1).columns)
importance = importance.sort_values(by='Importance', axis=0, ascending=True)
importance.plot(kind='barh', color='r')
plt.xlabel('Variable Importance')
plt.title('Random Forest Feature Importances')
plt.show()

# %%
boosted_model = GradientBoostingRegressor(n_estimators=500, learning_rate=0.01, max_depth=4, random_state=42)
boosted_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=4, n_estimators=500,
#                           random_state=42)

# %%
boosted_pred = boosted_model.predict(X_test)
boosted_mse = mean_squared_error(y_test, boosted_pred)
print(f'Gradient Boosting Regressor MSE: {boosted_mse}')
print(f'RMSE: {np.sqrt(boosted_mse)}')
# Out:
# Gradient Boosting Regressor MSE: 4.6367455414035925
# RMSE: 2.1533103681085066

# %%
boosted_model2 = GradientBoostingRegressor(n_estimators=500, learning_rate=0.1, max_depth=5, random_state=42)
boosted_model2.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=500, random_state=42)

# %%
boosted_pred2 = boosted_model2.predict(X_test)
boosted_mse2 = mean_squared_error(y_test, boosted_pred2)
print(f'Gradient Boosting Regressor (max_depth=5) MSE: {boosted_mse2}')
print(f'RMSE: {np.sqrt(boosted_mse2)}')
# Out:
# Gradient Boosting Regressor (max_depth=5) MSE: 5.088423203026779
# RMSE: 2.2557533559826037

# %% [markdown]
# ### Sabrina's Note:
# My results are similar, but I achieved better results with Ridge and Lasso.
